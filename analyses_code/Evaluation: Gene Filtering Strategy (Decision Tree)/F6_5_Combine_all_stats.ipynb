# %%
## Combine all the summary statistics for the gene-pairs as input for the decision tree

# %% [markdown]
# # Libraries

# %%
import anndata as ad
import numpy as np
import pandas as pd
import scanpy as sc
from matplotlib import pyplot as plt
from scipy.sparse import issparse

# %%
import os

# %%
import scipy.stats as stats
import numpy as np

# %% [markdown]
# # Parameters

# %%
### Define dataset and cell-type for which to prepare

# %%
### dataset

# %%
dataset = 'oneK1K'

# %%
cell_type = 'CD8_T'

# %%
### Define which summary stats to use

# %%
expr_type = 'data' ### or 'RNA'/ 'data' ## specify whether to use normalized or raw based expression stats

# %%
### Path to the co-EQTL Files

# %%
data_path = '../data/current/coeqtl_mapping/co_qtls_sceqtlgen/'

## co_qtls_sceqtlgen can be replaced by co_qtls_decision_tree
## co_qtls_sceqtlgen: contains all for initial mapping run
## co_qtls_decision_tree: files for final decision tree filtered run

# %%
result_path = '../results/current/F6/'

# %%
result_path_analysis = "../data/current/coeqtl_mapping/co_qtls_sceqtlgen/analysis_" + dataset  + "/" + cell_type + "/"

# %% [markdown]
# # Functions

# %%
def get_r_thres(n, p_thres=0.975):
    t = stats.t.ppf(p_thres, n)
    return np.sqrt(1 / (((n - 2) / t ** 2) + 1))

# %% [markdown]
# # Data

# %%
### Get summary stats calculated in previous steps

# %% [markdown]
# ## 1) Correlation summary stats (mean correlation, max correlation etc. per gene-pair)

# %%
result_path_analysis
# Out:
# '../data/current/coeqtl_mapping/co_qtls_decision_tree/analysis_oneK1K/CD8_T/'

# %%
cor_summary_stats = pd.read_csv(result_path_analysis  + 'F6_Correlation_Summary_Stats_all.csv')

# %%
cor_summary_stats = cor_summary_stats[['gene_pair', 'mean_correlation', 'mean_abs_correlation', 'var_correlation', 'max_correlation', 'n_NA', 'n_not_NA']]

# %%
cor_summary_stats.shape
# Out:
# (47030365, 7)

# %%
cor_summary_stats
# Out:
#                gene_pair  mean_correlation  mean_abs_correlation  \
# 0         SUGP1_TNFRSF1B          0.004962              0.062006
# 1         SUGP1_TNFRSF25          0.006427              0.053139
# 2             SUGP1_TOE1          0.013783              0.056209
# 3           SUGP1_TOMM20         -0.005369              0.057851
# 4         SUGP1_TOR1AIP1          0.004191              0.057628
# ...                  ...               ...                   ...
# 47030360     ZMAT1_ZMAT5         -0.004078              0.049333
# 47030361     ZMAT5_ZNF41         -0.001395              0.049932
# 47030362    ZMAT5_ZNF75D         -0.002744              0.048654
# 47030363     ZMAT5_ZNF81         -0.008842              0.040711
# 47030364     ZMAT5_ZRSR2         -0.003895              0.052026
#
#           var_correlation  max_correlation  n_NA  n_not_NA
# 0                0.006261         0.417952   519       496
# 1                0.004873         0.268827   730       285
# 2                0.004832         0.150000   977        38
# 3                0.005376         0.309478   495       520
# 4                0.005581         0.386313   549       466
# ...                   ...              ...   ...       ...
# 47030360         0.003627         0.182506   909       106
# 47030361         0.004497         0.324365   842       173
# 47030362         0.003704         0.215466   836       179
# 47030363         0.002374         0.136821   951        64
# 47030364         0.004203         0.220221   747       268
#
# [47030365 rows x 7 columns]

# %%
### Extract gene 1 and gene2

# %%
cor_summary_stats['gene1'] = cor_summary_stats['gene_pair'].str.replace('_.*', '', regex = True)
cor_summary_stats['gene2'] = cor_summary_stats['gene_pair'].str.replace('.*_', '', regex = True)

# %% [markdown]
# ## 2) Expression summary stats (mean expression, variance , percentage zero etc. per gene)

# %%
result_path_analysis
# Out:
# '../data/current/coeqtl_mapping/co_qtls_decision_tree/analysis_oneK1K/CD8_T/'

# %%
if expr_type == 'data':
    expression_summary_stats = pd.read_csv(result_path_analysis  + 'F6_Expression_Summary_Stats_all_data.csv') # alternative with normalized data
if expr_type == 'RNA':
    expression_summary_stats = pd.read_csv(result_path_analysis  + 'F6_Expression_Summary_Stats_all.csv')

# %%
expression_summary_stats
# Out:
#        Unnamed: 0       gene  mean_expression  sd_sample_mean_expression  \
# 0               1       A1BG         0.092249                   0.037742
# 1               2   A1BG-AS1         0.031895                   0.010598
# 2               3        A2M         0.182415                   0.108957
# 3               4    A2M-AS1         0.091136                   0.036155
# 4               5  A2ML1-AS1         0.024959                   0.008998
# ...           ...        ...              ...                        ...
# 13029       13030       ZXDC         0.085154                   0.023146
# 13030       13031     ZYG11B         0.043337                   0.014220
# 13031       13032        ZYX         0.086619                   0.023932
# 13032       13033      ZZEF1         0.129043                   0.030666
# 13033       13034       ZZZ3         0.128076                   0.034207
#
#        mean_variance  sd_sample_variance  sum_non_zero  mean_non_zero  \
# 0           0.065164            0.033825         17261      23.014667
# 1           0.021689            0.010834          1280      13.061224
# 2           0.148347            0.096971         29558      36.581683
# 3           0.070729            0.035675         13406      24.242315
# 4           0.023648            0.009368            56      11.200000
# ...              ...                 ...           ...            ...
# 13029       0.063677            0.026809         16015      22.089655
# 13030       0.033271            0.016787          4078      14.512456
# 13031       0.061678            0.024970         17030      23.751743
# 13032       0.099616            0.041669         25942      29.580388
# 13033       0.099215            0.045094         25559      28.621501
#
#        mean_percentage_zero  sum_zero   mean_zero  mean_coef_var
# 0                 86.841141    123757  165.009333       2.918516
# 1                 94.874179     25859  263.867347       4.718715
# 2                 79.311047    115079  142.424505       2.379295
# 3                 87.887734     98584  178.271248       3.053253
# 4                 96.976541      1998  399.600000       6.311343
# ...                     ...       ...         ...            ...
# 13029             88.103565    123789  170.743448       2.991849
# 13030             93.839469     65746  233.971530       4.247124
# 13031             87.390285    122369  170.668061       2.927361
# 13032             83.016948    129504  147.667047       2.449801
# 13033             83.269195    131420  147.166853       2.464530
#
# [13034 rows x 12 columns]

# %%
### Add for gene1

# %%
expression_summary_stats_gene1 = expression_summary_stats.add_prefix('gene1_')

# %%
summary_stats = pd.merge(cor_summary_stats, expression_summary_stats_gene1, how = 'left', left_on = 'gene1', right_on = 'gene1_gene')

# %%
summary_stats.shape
# Out:
# (47030365, 21)

# %%
### Add for gene2

# %%
expression_summary_stats_gene2 = expression_summary_stats.add_prefix('gene2_')

# %%
summary_stats = pd.merge(summary_stats, expression_summary_stats_gene2, how = 'left', left_on = 'gene2', right_on = 'gene2_gene')

# %%
summary_stats.shape
# Out:
# (47030365, 33)

# %% [markdown]
# ## 3) Paired expression summary stats (mean paired zero, zero one cell etc.)

# %%
if os.path.isfile(result_path_analysis  + 'Paired_expression_summary_all.csv'):
    paired_expression_stats = pd.read_csv(result_path_analysis  + 'Paired_expression_summary_all.csv')
else:
    # Define the columns
    columns = ['gene_pair', 'n_sample', 'mean_paired_non_zero', 'mean_paired_zero', 'mean_zero_one_cell', 'mean_non_zero_one_cell']
    # Create an empty DataFrame with specified columns
    paired_expression_stats = pd.DataFrame(columns=columns)

# %%
#paired_expression_stats = pd.read_csv(result_path_analysis  + 'Paired_expression_summary_all.csv')

# %%
paired_expression_stats
# Out:
# Empty DataFrame
# Columns: [gene_pair, n_sample, mean_paired_non_zero, mean_paired_zero, mean_zero_one_cell, mean_non_zero_one_cell]
# Index: []

# %%
summary_stats = pd.merge(summary_stats, paired_expression_stats, how = 'left', left_on = 'gene_pair', right_on = 'gene_pair')

# %%
summary_stats.shape
# Out:
# (47030365, 38)

# %% [markdown]
# ## Save the combined dataset for usage in decision tree analysis

# %%
summary_stats[0:6]
# Out:
#         gene_pair  mean_correlation  mean_abs_correlation  var_correlation  \
# 0  SUGP1_TNFRSF1B          0.004962              0.062006         0.006261
# 1  SUGP1_TNFRSF25          0.006427              0.053139         0.004873
# 2      SUGP1_TOE1          0.013783              0.056209         0.004832
# 3    SUGP1_TOMM20         -0.005369              0.057851         0.005376
# 4  SUGP1_TOR1AIP1          0.004191              0.057628         0.005581
# 5  SUGP1_TOR1AIP2         -0.000023              0.055735         0.004781
#
#    max_correlation  n_NA  n_not_NA  gene1     gene2  gene1_Unnamed: 0  ...  \
# 0         0.417952   519       496  SUGP1  TNFRSF1B             10862  ...
# 1         0.268827   730       285  SUGP1  TNFRSF25             10862  ...
# 2         0.150000   977        38  SUGP1      TOE1             10862  ...
# 3         0.309478   495       520  SUGP1    TOMM20             10862  ...
# 4         0.386313   549       466  SUGP1  TOR1AIP1             10862  ...
# 5         0.216183   557       458  SUGP1  TOR1AIP2             10862  ...
#
#   gene2_mean_non_zero  gene2_mean_percentage_zero  gene2_sum_zero  \
# 0           30.103880                   83.250444          122461
# 1           17.587822                   91.102698           84039
# 2           12.814815                   95.516050           16191
# 3           56.672746                   65.005954          106352
# 4           19.943425                   89.678985          118782
# 5           19.947853                   89.846062          119090
#
#    gene2_mean_zero  gene2_mean_coef_var  n_sample  mean_paired_non_zero  \
# 0       153.267835             2.592668       NaN                   NaN
# 1       196.812646             3.614241       NaN                   NaN
# 2       299.833333             5.019318       NaN                   NaN
# 3       107.752786             1.561175       NaN                   NaN
# 4       181.623853             3.223934       NaN                   NaN
# 5       182.653374             3.268995       NaN                   NaN
#
#    mean_paired_zero  mean_zero_one_cell  mean_non_zero_one_cell
# 0               NaN                 NaN                     NaN
# 1               NaN                 NaN                     NaN
# 2               NaN                 NaN                     NaN
# 3               NaN                 NaN                     NaN
# 4               NaN                 NaN                     NaN
# 5               NaN                 NaN                     NaN
#
# [6 rows x 38 columns]

# %%
## Save

# %%
if expr_type == 'data':
    summary_stats.to_csv(result_path_analysis + 'F6_Summary_Stats_all_data.csv') # alternative with normalized expression stats    
if expr_type == 'RNA':
    summary_stats.to_csv(result_path_analysis + 'F6_Summary_Stats_all.csv')

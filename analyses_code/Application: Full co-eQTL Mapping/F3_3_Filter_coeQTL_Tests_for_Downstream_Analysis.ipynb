# %%
## Load results from co-eQTL pipeline and save as .csv for further downstream analyses
## Filter co-eQTL testing files, e.g. all tests for significant gene-pairs, eGenes etc.

# %% [markdown]
# # Libraries

# %%
import anndata as ad
import numpy as np
import pandas as pd
import scanpy as sc
from matplotlib import pyplot as plt
from scipy.sparse import issparse

# %%
import math

# %%
import os

# %%
from sklearn.metrics import mean_squared_error

# %%
import scipy.stats as stats
import numpy as np

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.utils import Bunch
from sklearn.tree import plot_tree
from sklearn.feature_selection import mutual_info_classif
import pandas as pd 
import numpy as np

# %%
import random

# %%
import datetime

# %%
# import the regressor 
from sklearn.tree import DecisionTreeRegressor

# %%
import seaborn as sns

# %% [markdown]
# # Parameters

# %%
### which co-eqtl mapping results

# %%
coeqtl_results_path = 'co_qtls_decision_tree/'   # path to final mapping results (based on decision tree filter)
coeqtl_results_path_old = 'co_qtls_sceqtlgen/'   # path to initial evaluation phase co-eQTL results

# %%
### Path to the co-EQTL Files

# %%
data_path = '../data/current/coeqtl_mapping/'

# %%
### Path to the eQTL files from sceQTLGen

# %%
data_path_eqtl = '../data/current/eqtl_mapping/'

# %%
eqtl_results = 'sc_eqtlgen_final'

# %%
### Path to store results

# %%
result_path = '../results/current/F3/'

# %%
result_path_analysis =  "../data/current/coeqtl_mapping/" + coeqtl_results_path + "analysis"

# %%
### Path to meta-data files

# %%
data_path_meta = '../data/current/meta-data'

# %%
### Parameters for determination of significant co-eQTLs

# %%
p_value_sign = 0.05

# %%
n_sample_filter = 133

# %%
mt_correction = 'eGene_bf' # eGene_bf, p_val_mt

# %%
snp_filter = ''

# %% [markdown]
# # Data

# %% [markdown]
# ## Load the significant co-eQTLs

# %%
### Load the nominally significant co-QTLs from each single-cell dataset

# %%
### Define cell-types and datasets for which to execute

# %%
datasets_to_load = ['oneK1K']

#datasets_to_load = ['oneK1K', 'Franke_v2'  , 'Franke_v3', 'wijst', 'multiome']

# %%
cell_types = ['NK', 'CD4_T', 'CD8_T', 'Mono', 'B']

# %%
# Initialize an empty DataFrame to store the results
coeqtl_results = pd.DataFrame()

# Loop through each dataset and cell type
for i in datasets_to_load:
    for j in cell_types:
        # Construct the file path
        if n_sample_filter > 0:
            n_sample_filter_param = 'TRUE'
        if n_sample_filter == 0:
            n_sample_filter_param = 'FALSE'
        #file_path = f"{result_path_analysis}_{i}/{j}/F3_Co_E_Genes" + n_sample_filter_param + '_' + snp_filter + ".csv"
        file_path = f"{result_path_analysis}_{i}/{j}/F3_Co_E_Genes" + n_sample_filter_param +  ".csv"
        print(datetime.datetime.fromtimestamp(os.path.getmtime(file_path)))
        
        # Check if the file exists
        if os.path.exists(file_path):
            # Read the CSV file into a DataFrame
            result_file = pd.read_csv(file_path)
            
            # Add the dataset and cell_type columns
            result_file['dataset'] = i
            result_file['cell_type'] = j
            
            # Append the result to the coeqtl_results DataFrame
            coeqtl_results = pd.concat([coeqtl_results, result_file], ignore_index=True)
# Out:
# 2025-03-14 16:52:36
# 2025-03-19 11:34:45
# 2025-03-14 14:48:45
# 2025-03-14 14:44:43
# 2025-03-14 15:52:22

# %%
### Filter the file based on multiple testing correction method

# %%
if mt_correction  == 'eGene_bf':
    coeqtl_results = coeqtl_results[coeqtl_results['p_val_mt_eGene'] < coeqtl_results['p_q_cutoff']]

# %%
## Filter only bonferroni significant results
if mt_correction  != 'eGene_bf':
    coeqtl_results = coeqtl_results[coeqtl_results['p_val_mt'] < 0.05]  # how to define significance

# %%
### Load the significant co-eQTLs from the meta-analysis

# %%
# Initialize an empty DataFrame to store the results
meta_results = pd.DataFrame()
cell_types = [ 'NK', 'B', 'CD8_T', 'Mono', 'CD4_T']

# Loop through each dataset and cell type

for j in cell_types:
    # Construct the file path
    #file_path =  "../data/current/coeqtl_mapping/" + coeqtl_results_path +   '/meta_analysis/' + 'meta_5ds/' + j + '/Meta_Analysis_Sign_results' +  str(n_sample_filter) + '_' + snp_filter +  '.csv' 
    file_path =  "../data/current/coeqtl_mapping/" + coeqtl_results_path +   '/meta_analysis/' + 'meta_5ds/' + j + '/Meta_Analysis_Sign_results' +  str(n_sample_filter) +   '.csv' 

    # Check if the file exists
    if os.path.exists(file_path):
        # Read the CSV file into a DataFrame
        result_file = pd.read_csv(file_path)
        print(datetime.datetime.fromtimestamp(os.path.getmtime(file_path)))

        # Add the dataset and cell_type columns
        result_file['cell_type'] = j

        # Append the result to the coeqtl_results DataFrame
        meta_results = pd.concat([meta_results, result_file], ignore_index=True)
# Out:
# 2024-10-15 10:47:28
# 2025-02-12 16:10:20
# 2024-10-15 11:00:27
# 2025-02-12 17:13:29
# 2024-10-15 11:39:25

# %%
### Filter meta-analysis results based on multiple correction p-value threshold

# %%
if mt_correction  == 'eGene_bf':
    meta_results = meta_results[meta_results['p_val_mt_eGene'] < meta_results['p_q_cutoff']]

# %%
meta_results
# Out:
#           Unnamed: 0                              coQTL              eGene  \
# 0                  1        12:56007301:G:A;RPS26_RPL41              RPS26
# 1                  2        12:56007301:G:A;RPS26_RPS27              RPS26
# 2                  3        12:56007301:G:A;RPS26_RPS29              RPS26
# 3                  4        12:56042145:C:G;RPS26_RPL41              RPS26
# 4                  5        12:56042145:C:G;RPS26_RPS27              RPS26
# ...              ...                                ...                ...
# 23789512     8693916           11:65885771:C:T;FAU_CTSW           CTSW_FAU
# 23789513     8693917  18:24001745:T:C;TTC39C_TTC39C-AS1  TTC39C_TTC39C-AS1
# 23789514     8693918   6:32658495:C:A;HLA-DRB1_HLA-DQB1  HLA-DQB1_HLA-DRB1
# 23789533     8693937           12:8971336:T:C;A2M_KLRB1          A2M_KLRB1
# 23789546     8693950           12:8992460:T:C;A2M_KLRB1          A2M_KLRB1
#
#           feature_chromosome  feature_start  feature_end            coeGene  \
# 0                         12       56041351     56044676              RPL41
# 1                         12       56041351     56044676              RPS27
# 2                         12       56041351     56044676              RPS29
# 3                         12       56041351     56044676              RPL41
# 4                         12       56041351     56044676              RPS27
# ...                      ...            ...          ...                ...
# 23789512                  11       65120628     65122473           CTSW_FAU
# 23789513                  18       23992773     24135610  TTC39C_TTC39C-AS1
# 23789514                   6       32578769     32589848  HLA-DQB1_HLA-DRB1
# 23789533                  12        9067664      9116229          A2M_KLRB1
# 23789546                  12        9067664      9116229          A2M_KLRB1
#
#                  feature_id           snp_id  snp_position  ...  \
# 0               RPL41_RPS26  12:56007301:G:A      56007301  ...
# 1               RPS26_RPS27  12:56007301:G:A      56007301  ...
# 2               RPS26_RPS29  12:56007301:G:A      56007301  ...
# 3               RPL41_RPS26  12:56042145:C:G      56042145  ...
# 4               RPS26_RPS27  12:56042145:C:G      56042145  ...
# ...                     ...              ...           ...  ...
# 23789512           CTSW_FAU  11:65885771:C:T      65885771  ...
# 23789513  TTC39C_TTC39C-AS1  18:24001745:T:C      24001745  ...
# 23789514  HLA-DQB1_HLA-DRB1   6:32658495:C:A      32658495  ...
# 23789533          A2M_KLRB1   12:8971336:T:C       8971336  ...
# 23789546          A2M_KLRB1   12:8992460:T:C       8992460  ...
#
#                                     triplet  is_rb_mt  p_val_mt  \
# 0               12:56007301:G:A;RPL41_RPS26         1  0.000000
# 1               12:56007301:G:A;RPS26_RPS27         1  0.000000
# 2               12:56007301:G:A;RPS26_RPS29         1  0.000000
# 3               12:56042145:C:G;RPL41_RPS26         1  0.000000
# 4               12:56042145:C:G;RPS26_RPS27         1  0.000000
# ...                                     ...       ...       ...
# 23789512           11:65885771:C:T;CTSW_FAU         1  0.151367
# 23789513  18:24001745:T:C;TTC39C_TTC39C-AS1         0  0.169862
# 23789514   6:32658495:C:A;HLA-DQB1_HLA-DRB1         0  0.209483
# 23789533           12:8971336:T:C;A2M_KLRB1         0  1.558180
# 23789546           12:8992460:T:C;A2M_KLRB1         0  3.490753
#
#           amount_tests_eGene  p_val_mt_eGene  p_bh_cutoff p_q_cutoff  \
# 0                     172827        0.000000     0.001380   0.001380
# 1                     172827        0.000000     0.001380   0.001380
# 2                     172827        0.000000     0.001380   0.001380
# 3                     172827        0.000000     0.001380   0.001380
# 4                     172827        0.000000     0.001380   0.001380
# ...                      ...             ...          ...        ...
# 23789512              162076        0.000154     0.002728   0.002728
# 23789513                8053        0.000009     0.002728   0.002728
# 23789514             1742214        0.002290     0.002728   0.002728
# 23789533               97252        0.000951     0.002728   0.002728
# 23789546               97252        0.002130     0.002728   0.002728
#
#                type  cell_type  q_value
# 0            unique         NK      NaN
# 1            unique         NK      NaN
# 2            unique         NK      NaN
# 3            unique         NK      NaN
# 4            unique         NK      NaN
# ...             ...        ...      ...
# 23789512  duplicate      CD4_T      NaN
# 23789513  duplicate      CD4_T      NaN
# 23789514  duplicate      CD4_T      NaN
# 23789533  duplicate      CD4_T      NaN
# 23789546  duplicate      CD4_T      NaN
#
# [91628 rows x 42 columns]

# %%
if mt_correction  != 'eGene_bf':  # Bonferroni threshold
    meta_results = meta_results[meta_results['p_val_mt'] < 0.05]

# %%
### Define the sign gene-pair and eGenes for which to save all the tests

# %%
### All significant gene-pairs

# %%
sign_gene_pairs = pd.unique(pd.concat([coeqtl_results['feature_id'], meta_results['feature_id']]))

# %%
### All significant eGenes

# %%
sign_egenes_sc_datasets = coeqtl_results.drop_duplicates(['eGene', 'snp_id'])[['eGene', 'snp_id']]
sign_egenes_meta = meta_results.drop_duplicates(['eGene', 'snp_id'])[['eGene', 'snp_id']]

# %%
sign_egenes_sc_datasets['egene_snp_id'] = sign_egenes_sc_datasets['eGene'] + ';' +  sign_egenes_sc_datasets['snp_id']
sign_egenes_meta['egene_snp_id'] = sign_egenes_meta['eGene'] + ';' +  sign_egenes_meta['snp_id']

# %%
sign_egenes = pd.concat([sign_egenes_sc_datasets, sign_egenes_meta], ignore_index=True)

# %%
sign_egenes = sign_egenes.drop_duplicates()

# %%
sign_egenes
# Out:
#                   eGene           snp_id                      egene_snp_id
# 0                 RPS26  12:55991020:G:A             RPS26;12:55991020:G:A
# 1                 RPS26  12:55995509:T:C             RPS26;12:55995509:T:C
# 2                 RPS26  12:56001170:A:G             RPS26;12:56001170:A:G
# 3                 RPS26  12:56007301:G:A             RPS26;12:56007301:G:A
# 4                 RPS26  12:56042145:C:G             RPS26;12:56042145:C:G
# ...                 ...              ...                               ...
# 2001        GLIPR1_KRR1  12:75493570:A:G       GLIPR1_KRR1;12:75493570:A:G
# 2005           CTSW_FAU  11:65885771:C:T          CTSW_FAU;11:65885771:C:T
# 2007  HLA-DQB1_HLA-DRB1   6:32658495:C:A  HLA-DQB1_HLA-DRB1;6:32658495:C:A
# 2008          A2M_KLRB1   12:8971336:T:C          A2M_KLRB1;12:8971336:T:C
# 2009          A2M_KLRB1   12:8992460:T:C          A2M_KLRB1;12:8992460:T:C
#
# [1161 rows x 3 columns]

# %%
len(pd.unique(sign_egenes['eGene']))
# Out:
# 362

# %%
len(pd.unique(sign_egenes['egene_snp_id']))
# Out:
# 1161

# %% [markdown]
# ## Get the tests for each sign gene-pair (in the meta-analysis)

# %%
datasets_to_load = ['meta_analysis']

# %%
cell_types = ['CD4_T', 'Mono', 'NK', 'B', 'CD8_T']

# %%
# Initialize an empty DataFrame to store the results
executed_tests = pd.DataFrame()


# Loop through each dataset and cell type
for i in datasets_to_load:
    for j in cell_types:
        # Construct the file path
        file_path = data_path + '/' +coeqtl_results_path  + '/'+ i + '/'  + 'meta_5ds/' + j + '/meta_qtl_results_all.txt.gz'

        # Check if the file exists
        if os.path.exists(file_path):
            # Read the CSV file into a DataFrame
            result_file = pd.read_csv(file_path, sep = '\t')

            result_file = result_file[result_file['feature_id'].isin(sign_gene_pairs)]

            # Add the dataset and cell_type columns
            result_file['dataset'] = i
            result_file['cell_type'] = j

            # Append the result to the coeqtl_results DataFrame
            executed_tests = pd.concat([executed_tests, result_file], ignore_index=True)
            del result_file

# %%
pd.unique(executed_tests['cell_type'])

# %%
pd.unique(executed_tests['dataset'])

# %%
executed_tests

# %%
### Save the file for further analysis

# %%
executed_tests.to_csv(data_path + coeqtl_results_path + '/tests_sign_pairs/Tests_executed_on_sign_gene_pairs_meta' +  str(n_sample_filter)  + '.csv')

# %% [markdown]
# ## Get the tests for each sign gene-pair (in the single-datasets)

# %%
datasets_to_load = ['oneK1K', 'Franke_v2'  , 'Franke_v3', 'wijst', 'multiome']

# %%
cell_types = ['CD4_T', 'Mono', 'NK', 'B', 'CD8_T']

# %%
# Initialize an empty DataFrame to store the results
executed_tests = pd.DataFrame()

# Loop through each dataset and cell type
for i in datasets_to_load:
    for j in cell_types:
        # Construct the file path
        #file_path = data_path + '/' +coeqtl_results_path  + '/'+ i + '/' + j + '/F3_decision_tree_input.csv.gz'
        file_path = data_path + '/' +coeqtl_results_path  + '/'+ i + '/' + j + '/qtl_results_all_unqid.csv.gz'  # changed to ensure to have all tests not only those filtered based on n_sample

        # Check if the file exists
        if os.path.exists(file_path):
            # Read the CSV file into a DataFrame
            result_file = pd.read_csv(file_path)

            result_file = result_file[result_file['feature_id'].isin(sign_gene_pairs)]

            # Add the dataset and cell_type columns
            result_file['dataset'] = i
            result_file['cell_type'] = j

            # Append the result to the coeqtl_results DataFrame
            executed_tests = pd.concat([executed_tests, result_file], ignore_index=True)
            del result_file

# %%
pd.unique(executed_tests['cell_type'])
# Out:
# array(['CD4_T', 'Mono', 'NK', 'B', 'CD8_T'], dtype=object)

# %%
pd.unique(executed_tests['dataset'])
# Out:
# array(['oneK1K', 'Franke_v2', 'Franke_v3', 'wijst', 'multiome'],
#       dtype=object)

# %%
executed_tests
# Out:
#          Unnamed: 0      feature_id           snp_id   p_value  beta  beta_se  \
# 0             42372      A1BG_RPS26  12:55975722:A:G  0.397208   NaN      NaN
# 1             42373      A1BG_RPS26  12:55991020:G:A  0.506004   NaN      NaN
# 2             42374      A1BG_RPS26  12:55991795:C:T  0.850009   NaN      NaN
# 3             42375      A1BG_RPS26  12:55995509:T:C  0.512736   NaN      NaN
# 4             42376      A1BG_RPS26  12:56001170:A:G  0.458205   NaN      NaN
# ...             ...             ...              ...       ...   ...      ...
# 3634060    86741372  HLA-DRB1_RPS28   6:32457527:A:G  1.000000   NaN      NaN
# 3634061    86741373  HLA-DRB1_RPS28   6:32459604:G:T  1.000000   NaN      NaN
# 3634062    86741421  HLA-DRB1_UBA52   6:33072321:C:T  1.000000   NaN      NaN
# 3634063    86741422  HLA-DRB1_UBA52   6:33092341:G:A  1.000000   NaN      NaN
# 3634064    86741423  HLA-DRB1_UBA52   6:33104395:T:G  1.000000   NaN      NaN
#
#          empirical_feature_p_value  feature_chromosome  feature_start  \
# 0                              NaN                  12       56041351
# 1                              NaN                  12       56041351
# 2                              NaN                  12       56041351
# 3                              NaN                  12       56041351
# 4                              NaN                  12       56041351
# ...                            ...                 ...            ...
# 3634060                        NaN                   6       32578769
# 3634061                        NaN                   6       32578769
# 3634062                        NaN                   6       32578769
# 3634063                        NaN                   6       32578769
# 3634064                        NaN                   6       32578769
#
#          feature_end  ... snp_position  closeGenes       z_score  \
# 0           56044676  ...   55975722.0       False -8.469810e-01
# 1           56044676  ...   55991020.0       False -6.653110e-01
# 2           56044676  ...   55991795.0       False  1.891558e-01
# 3           56044676  ...   55995509.0       False -6.548161e-01
# 4           56044676  ...   56001170.0       False -7.420924e-01
# ...              ...  ...          ...         ...           ...
# 3634060     32589848  ...   32457527.0       False  9.521116e-17
# 3634061     32589848  ...   32459604.0       False  9.521116e-17
# 3634062     32589848  ...   33072321.0       False -4.760558e-17
# 3634063     32589848  ...   33092341.0       False -4.760558e-17
# 3634064     32589848  ...   33104395.0       False -4.760558e-17
#
#                             triplet n_samples n_e_samples  gene1     gene2  \
# 0        A1BG_RPS26;12:55975722:A:G       992         992  RPS26      A1BG
# 1        A1BG_RPS26;12:55991020:G:A       992         992  RPS26      A1BG
# 2        A1BG_RPS26;12:55991795:C:T       992         992  RPS26      A1BG
# 3        A1BG_RPS26;12:55995509:T:C       992         992  RPS26      A1BG
# 4        A1BG_RPS26;12:56001170:A:G       992         992  RPS26      A1BG
# ...                             ...       ...         ...    ...       ...
# 3634060                         NaN        24          24  RPS28  HLA-DRB1
# 3634061                         NaN        24          24  RPS28  HLA-DRB1
# 3634062                         NaN        24          24  UBA52  HLA-DRB1
# 3634063                         NaN        24          24  UBA52  HLA-DRB1
# 3634064                         NaN        24          24  UBA52  HLA-DRB1
#
#           dataset cell_type
# 0          oneK1K     CD4_T
# 1          oneK1K     CD4_T
# 2          oneK1K     CD4_T
# 3          oneK1K     CD4_T
# 4          oneK1K     CD4_T
# ...           ...       ...
# 3634060  multiome     CD8_T
# 3634061  multiome     CD8_T
# 3634062  multiome     CD8_T
# 3634063  multiome     CD8_T
# 3634064  multiome     CD8_T
#
# [3634065 rows x 26 columns]

# %%
### Save the file for further analysis

# %%
executed_tests.to_csv(data_path + coeqtl_results_path + '/tests_sign_pairs/Tests_executed_on_sign_gene_pairs' +   str(n_sample_filter)  +  mt_correction + '_' + snp_filter + '.csv')

# %% [markdown]
# ## Get tests for each sign egene (in the single datasets)

# %%
datasets_to_load = ['oneK1K']

# %%
cell_types = ['CD4_T', 'Mono', 'NK', 'B', 'CD8_T']
# ['CD4_T', 'Mono', 'NK', 'B', 'CD8_T']

# %%
# Initialize an empty DataFrame to store the results
executed_tests = pd.DataFrame()

# Loop through each dataset and cell type
for i in datasets_to_load:
    for j in cell_types:
        # Construct the file path
        file_path = data_path + '/' +coeqtl_results_path  + '/'+ i + '/' + j + '/F3_decision_tree_input.csv.gz'

        # Check if the file exists
        if os.path.exists(file_path):
            # Read the CSV file into a DataFrame
            result_file = pd.read_csv(file_path)
            
            
            ### Remove unnnecessary columns
            del result_file['empirical_feature_p_value']
            del result_file ['feature_chromosome']
            #del result_file['test1']
            #del result_file['test2']
            #del result_file['test3']
            del result_file['feature_start']
            del result_file['feature_end']
            #del result_file['biotype']
            #del result_file['index']
            del result_file[ 'alpha_param']
            del result_file['beta_param']

           ### Add columns for filtering
            result_file['gene1_snp_id'] = result_file['gene1'] + ';' + result_file['snp_id']
            result_file['gene2_snp_id'] = result_file['gene2'] + ';' + result_file['snp_id']

            ### Filter result file on results for significant egenes
            result_file =  result_file[(result_file['gene1_snp_id'].isin(pd.unique(sign_egenes['egene_snp_id']))) | (result_file['gene2_snp_id'].isin(pd.unique(sign_egenes['egene_snp_id'])))  ]

            # Add the dataset and cell_type columns
            result_file['dataset'] = i
            result_file['cell_type'] = j

            # Append the result to the coeqtl_results DataFrame
            executed_tests = pd.concat([executed_tests, result_file], ignore_index=True)
            del result_file
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1734574/1546546559.py", line 13, in <module>
#     result_file = pd.read_csv(file_path)
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 626, in _read
#     return parser.read(nrows)
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 1923, in read
#     ) = self._engine.read(  # type: ignore[attr-defined]
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py", line 234, in read
#     chunks = self._reader.read_low_memory(nrows)
#   File "parsers.pyx", line 838, in pandas._libs.parsers.TextReader.read_low_memory
#   File "parsers.pyx", line 921, in pandas._libs.parsers.TextReader._read_rows
#   File "parsers.pyx", line 1083, in pandas._libs.parsers.TextReader._convert_column_data
#   File "parsers.pyx", line 1456, in pandas._libs.parsers._maybe_upcast
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/numpy/core/multiarray.py", line 1131, in putmask
#     @array_function_from_c_func_and_dispatcher(_multiarray_umath.putmask)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/inspect.py", line 752, in getmodule
#     f = getabsfile(module)
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/inspect.py", line 721, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/inspect.py", line 706, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/icb/corinna.losert/miniconda3/envs/scgrn_R_4_1/lib/python3.9/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_1734574/1546546559.py in <module>
#      12             # Read the CSV file into a DataFrame
# ---> 13             result_file = pd.read_csv(file_path)
#      14
#
# ~/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#
# ~/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     625     with parser:
# --> 626         return parser.read(nrows)
#     627
#
# ~/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1922                     col_dict,
# -> 1923                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1924                     nrows
#
# ~/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#
# parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# parsers.pyx in pandas._libs.parsers._maybe_upcast()
#
# ~/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/numpy/core/multiarray.py in putmask(a, mask, values)
#    1130
# -> 1131 @array_function_from_c_func_and_dispatcher(_multiarray_umath.putmask)
#    1132 def putmask(a, /, mask, values):
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2061                         stb = value._render_traceback_()
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#    2065
#
# ~/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# ~/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/miniconda3/envs/scgrn_R_4_1/lib/python3.9/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
### Save the file for further analysis

# %%
executed_tests.to_csv(data_path + coeqtl_results_path + '/tests_sign_pairs/Tests_executed_on_sign_egenes' +   str(n_sample_filter)  +  mt_correction + '.csv.gz', compression='gzip')

# %%
#executed_tests

# %% [markdown]
# ## Get tests for each sign egene (in the meta-analysis)

# %%
datasets_to_load = ['meta_analysis']

# %%
cell_types = [ 'Mono', 'NK', 'B', 'CD8_T', 'CD4_T']
# ['CD4_T', 'Mono', 'NK', 'B', 'CD8_T']

# %%
j
# Out:
# 'CD8_T'

# %%
# Initialize an empty DataFrame to store the results
executed_tests = pd.DataFrame()

# Loop through each dataset and cell type
for i in datasets_to_load:
    for j in cell_types:
        # Construct the file path
        file_path = data_path + '/' +coeqtl_results_path  + '/'+ i + '/'  + 'meta_5ds/' + j + '/meta_qtl_results_all.txt.gz'

        # Check if the file exists
        if os.path.exists(file_path):
            # Read the CSV file into a DataFrame
            result_file = pd.read_csv(file_path, sep = '\t')

           ### Add columns for filtering
            result_file['eGene_snp_id'] = result_file['eGene'] + ';' + result_file['snp_id']
            #result_file['gene2_snp_id'] = result_file['gene2'] + ';' + result_file['snp_id']

            ### Filter result file on results for significant egenes
            result_file =  result_file[(result_file['eGene_snp_id'].isin(pd.unique(sign_egenes['egene_snp_id'])))  ]
            result_file = result_file[['coQTL', 'eGene',  'coeGene', 'feature_id', 'snp_id', 'snp_position', 'closeGenes', 'p_value', 'n_samples']]

            # Add the dataset and cell_type columns
            result_file['dataset'] = i
            result_file['cell_type'] = j

            # Append the result to the coeqtl_results DataFrame
            executed_tests = pd.concat([executed_tests, result_file], ignore_index=True)
            del result_file

# %%
### Save the file for further analysis

# %%
executed_tests.to_csv(data_path + coeqtl_results_path + '/tests_sign_pairs/Tests_executed_on_sign_egenes_meta_5ds' +   str(n_sample_filter)  +  mt_correction + '.csv.gz', compression='gzip')

# %%
executed_tests['ident'] = executed_tests['eGene'] + ';' +  executed_tests['snp_id']

# %%
### Add to the tests whether significant co-EQTL in meta-analysis or not

# %%
meta_results['coeQTL'] = 1

# %%
executed_tests

# %%
result = pd.merge(executed_tests, meta_results[['eGene', 'coeGene', 'snp_id', 'cell_type', 'coeQTL']], on=['eGene', 'coeGene', 'snp_id', 'cell_type'], how='left')

# %%
sum(meta_results['coeQTL'][meta_results['cell_type'] == 'Mono'])

# %%
result['coeQTL'] = result['coeQTL'].fillna(0)

# %%
result

# %%
sum(result['coeQTL'][result['cell_type'] == 'B'])

# %%
sum(result['coeQTL'])

# %%
result.to_csv(data_path + coeqtl_results_path + '/tests_sign_pairs/Tests_executed_on_sign_egenes_meta_5ds_incl_annot' +   str(n_sample_filter)  +  mt_correction + '.csv.gz', compression='gzip')
